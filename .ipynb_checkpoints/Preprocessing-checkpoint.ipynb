# %%
import pandas as pd
import os


def load_hotel_reserve():
  customer_tb = pd.read_csv('./data/customer.csv')
  hotel_tb = pd.read_csv('./data/hotel.csv')
  reserve_tb = pd.read_csv('./data/reserve.csv')
  return customer_tb, hotel_tb, reserve_tb


def load_holiday_mst():
  holiday_tb = pd.read_csv('./data/holiday_mst.csv',
                           index_col=False)
  return holiday_tb


def load_production():
  production_tb = pd.read_csv('./data/production.csv')
  return production_tb


def load_production_missing_num():
  production_miss_num = pd.read_csv('./data/production_missing_num.csv')
  return production_miss_num


def load_production_missing_category():
  production_miss_cat = pd.read_csv('./data/production_missing_category.csv')
  return production_miss_cat


def load_monthly_index():
  monthly_index_tb = \
    pd.read_csv('./data/monthly_index.csv')
  return monthly_index_tb


def load_meros_txt():
  with open('./data/txt/meros.txt', 'r') as f:
    meros = f.read()
    f.close()
  return meros

# %%
holiday_tb = load_holiday_mst()
customer_tb, hotel_tb, reserve_tb = load_hotel_reserve()
meros = load_meros_txt()
monthly_index_tb = load_monthly_index()
production_tb = load_production()
production_miss_num = load_production_missing_num()
production_miss_cat = load_production_missing_category()

# %%
reserve_tb.iloc[:, 0:6]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time
# 0        10:00:00
# 1        11:30:00
# 2        09:00:00
# 3        11:00:00
# 4        10:30:00
# ...           ...
# 4025     09:30:00
# 4026     10:30:00
# 4027     11:30:00
# 4028     09:30:00
# 4029     09:00:00
#
# [4030 rows x 6 columns]

# %%
reserve_tb.columns
# Out:
# Index(['reserve_id', 'hotel_id', 'customer_id', 'reserve_datetime',
#        'checkin_date', 'checkin_time', 'checkout_date', 'people_num',
#        'total_price'],
#       dtype='object')

# %%
cols = ['reserve_id', 'hotel_id', 'customer_id', 'reserve_datetime',
       'checkin_date', 'checkin_time', 'checkout_date', #'people_num',
       #'total_price'
       ]

# %%
reserve_tb[cols]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date
# 0        10:00:00    2016-03-29
# 1        11:30:00    2016-07-21
# 2        09:00:00    2016-10-22
# 3        11:00:00    2017-03-30
# 4        10:30:00    2017-09-23
# ...           ...           ...
# 4025     09:30:00    2017-07-11
# 4026     10:30:00    2017-10-10
# 4027     11:30:00    2018-04-04
# 4028     09:30:00    2016-05-13
# 4029     09:00:00    2016-07-09
#
# [4030 rows x 7 columns]

# %%
reserve_tb.loc[:, cols]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date
# 0        10:00:00    2016-03-29
# 1        11:30:00    2016-07-21
# 2        09:00:00    2016-10-22
# 3        11:00:00    2017-03-30
# 4        10:30:00    2017-09-23
# ...           ...           ...
# 4025     09:30:00    2017-07-11
# 4026     10:30:00    2017-10-10
# 4027     11:30:00    2018-04-04
# 4028     09:30:00    2016-05-13
# 4029     09:00:00    2016-07-09
#
# [4030 rows x 7 columns]

# %%
reserve_tb.drop(['people_num', 'total_price'], axis = 1)
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
#
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 8            r9    h_217         c_2  2016-03-05 13:31:06   2016-03-25  \
# 9           r10    h_240         c_2  2016-06-25 09:12:22   2016-07-14
# 10          r11    h_183         c_2  2016-11-19 12:49:10   2016-12-08
# 11          r12    h_268         c_2  2017-05-24 10:06:21   2017-06-20
# 12          r13    h_223         c_2  2017-10-19 03:03:30   2017-10-21
# ...         ...      ...         ...                  ...          ...
# 4015      r4016    h_239       c_996  2016-12-29 02:10:09   2017-01-14
# 4016      r4017     h_96       c_996  2017-06-19 11:26:29   2017-07-05
# 4017      r4018    h_204       c_996  2017-08-20 17:56:37   2017-09-06
# 4018      r4019    h_224       c_996  2017-12-10 19:39:53   2017-12-20
# 4019      r4020    h_243       c_996  2018-04-22 20:41:29   2018-05-21
#
#      checkin_time checkout_date  people_num  total_price
# 8        09:30:00    2016-03-27           3        68400
# 9        11:00:00    2016-07-17           4       320400
# 10       11:00:00    2016-12-11           1        29700
# 11       09:00:00    2017-06-21           4        81600
# 12       09:30:00    2017-10-23           1       137000
# ...           ...           ...         ...          ...
# 4015     10:30:00    2017-01-16           2       226000
# 4016     10:30:00    2017-07-07           2        29600
# 4017     12:30:00    2017-09-07           2        24200
# 4018     11:30:00    2017-12-23           3        36000
# 4019     12:00:00    2018-05-22           2        55400
#
# [2093 rows x 9 columns]

# %%
rsv_cnt_tb = reserve_tb.groupby('hotel_id').size().reset_index()
rsv_cnt_tb.columns = ['hotel_id', 'rsv_cnt']

cus_cnt_tb = reserve_tb.groupby('hotel_id')['customer_id'].nunique().reset_index()

cus_cnt_tb.columns = ['hotel_id', 'cus_cnt']

pd.merge(rsv_cnt_tb, cus_cnt_tb, on='hotel_id')
# Out:
#     hotel_id  rsv_cnt  cus_cnt
# 0        h_1       10       10
# 1       h_10        3        3
# 2      h_100       20       19
# 3      h_101       17       17
# 4      h_102       13       13
# ..       ...      ...      ...
# 295     h_95       13       13
# 296     h_96       13       13
# 297     h_97       16       16
# 298     h_98       17       16
# 299     h_99       14       14
#
# [300 rows x 3 columns]

# %%
result = reserve_tb.groupby('hotel_id').agg({'reserve_id': 'count', 'customer_id': 'nunique'})

result = result.reset_index()
result.columns = ['hotel_id', 'rsv_cnt', 'cus_cnt']
display(result)
# Out:
#     hotel_id  rsv_cnt  cus_cnt
# 0        h_1       10       10
# 1       h_10        3        3
# 2      h_100       20       19
# 3      h_101       17       17
# 4      h_102       13       13
# ..       ...      ...      ...
# 295     h_95       13       13
# 296     h_96       13       13
# 297     h_97       16       16
# 298     h_98       17       16
# 299     h_99       14       14
#
# [300 rows x 3 columns]

# %%
result = reserve_tb.groupby(['hotel_id', 'people_num']).agg({'total_price': 'sum'})

result = result.reset_index()
result.columns = ['hotel_id', 'people_num', 'price_sum']
display(result)
# Out:
#      hotel_id  people_num  price_sum
# 0         h_1           1     156600
# 1         h_1           2     156600
# 2         h_1           3     391500
# 3         h_1           4     417600
# 4        h_10           1      11200
# ...       ...         ...        ...
# 1154     h_98           3     793800
# 1155     h_98           4     453600
# 1156     h_99           1     179200
# 1157     h_99           2     448000
# 1158     h_99           4    1164800
#
# [1159 rows x 3 columns]

# %%
result = reserve_tb.groupby(['hotel_id', 'people_num'])['total_price'].sum().reset_index()

result = result.rename(columns = {'total_price' : 'price_sum'})
display(result)
# Out:
#      hotel_id  people_num  price_sum
# 0         h_1           1     156600
# 1         h_1           2     156600
# 2         h_1           3     391500
# 3         h_1           4     417600
# 4        h_10           1      11200
# ...       ...         ...        ...
# 1154     h_98           3     793800
# 1155     h_98           4     453600
# 1156     h_99           1     179200
# 1157     h_99           2     448000
# 1158     h_99           4    1164800
#
# [1159 rows x 3 columns]

# %%
import numpy as np
result = reserve_tb.groupby('hotel_id').agg({'total_price': ['max', 'min', 'mean', 'median', lambda x: np.quantile(x, 0.2)]}).reset_index()
result.columns = ['hotel_id', 'max_price', 'min_price', 'avg_price', 'med_price', 'per_20price']

display(result)
# Out:
#     hotel_id  max_price  min_price      avg_price  med_price  per_20price
# 0        h_1     208800      26100  112230.000000   104400.0      73080.0
# 1       h_10      67200      11200   42933.333333    50400.0      26880.0
# 2      h_100      57600       4800   27600.000000    28800.0       9600.0
# 3      h_101     168000      14000   75764.705882    56000.0      30800.0
# 4      h_102      72000      12000   32769.230769    24000.0      18000.0
# ..       ...        ...        ...            ...        ...          ...
# 295     h_95     518400      43200  275815.384615   259200.0     146880.0
# 296     h_96      66600       7400   33015.384615    29600.0      17760.0
# 297     h_97     250800      20900   83600.000000    62700.0      20900.0
# 298     h_98     226800      18900   96723.529412    75600.0      56700.0
# 299     h_99     268800      44800  128000.000000    89600.0      67200.0
#
# [300 rows x 6 columns]

# %%
result = reserve_tb.groupby('hotel_id').agg({'total_price': ['var', 'std']}).reset_index()
result.columns = ['hotel_id', 'price_var', 'price_sd']
result = result.fillna(0)
display(result)
# Out:
#     hotel_id     price_var       price_sd
# 0        h_1  3.186549e+09   56449.526127
# 1       h_10  8.258133e+08   28736.968061
# 2      h_100  3.198316e+08   17883.835689
# 3      h_101  2.402441e+09   49014.703676
# 4      h_102  3.576923e+08   18912.755159
# ..       ...           ...            ...
# 295     h_95  3.313772e+10  182037.696857
# 296     h_96  3.159231e+08   17774.225072
# 297     h_97  5.474685e+09   73991.116584
# 298     h_98  3.432893e+09   58590.896578
# 299     h_99  5.745428e+09   75798.599541
#
# [300 rows x 3 columns]

# %%
reserve_tb['total_price'].round(-3).mode()
# Out:
# 0    10000
# 1    20000
# 2    40000
# Name: total_price, dtype: int64

# %%
reserve_tb['reserve_datetime'] = pd.to_datetime(reserve_tb['reserve_datetime'], format = '%Y-%m-%d %H:%M:%S')

reserve_tb['log_no'] = reserve_tb.groupby('customer_id')['reserve_datetime'].rank(ascending=True, method = 'first')

# %%
display(reserve_tb)
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000 2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000 2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price  log_no
# 0        10:00:00    2016-03-29           4        97200     1.0
# 1        11:30:00    2016-07-21           2        20600     2.0
# 2        09:00:00    2016-10-22           2        33600     3.0
# 3        11:00:00    2017-03-30           4       194400     4.0
# 4        10:30:00    2017-09-23           3        68100     5.0
# ...           ...           ...         ...          ...     ...
# 4025     09:30:00    2017-07-11           2        16000     4.0
# 4026     10:30:00    2017-10-10           2        41800     5.0
# 4027     11:30:00    2018-04-04           2        74800     6.0
# 4028     09:30:00    2016-05-13           4       540000     1.0
# 4029     09:00:00    2016-07-09           1        44100     2.0
#
# [4030 rows x 10 columns]

# %%
rsv_cnt_tb = reserve_tb.groupby('hotel_id').size().reset_index()
rsv_cnt_tb.columns = ['hotel_id', 'rsv_cnt']

rsv_cnt_tb['rsv_cnt_rank'] = rsv_cnt_tb['rsv_cnt'].rank(ascending = False, method = 'min')

rsv_cnt_tb = rsv_cnt_tb.drop('rsv_cnt', axis = 1)
display(rsv_cnt_tb)
# Out:
#     hotel_id  rsv_cnt_rank
# 0        h_1         235.0
# 1       h_10         300.0
# 2      h_100          12.0
# 3      h_101          43.0
# 4      h_102         139.0
# ..       ...           ...
# 295     h_95         139.0
# 296     h_96         139.0
# 297     h_97          60.0
# 298     h_98          43.0
# 299     h_99         115.0
#
# [300 rows x 2 columns]

# %%
pd.merge(reserve_tb, hotel_tb, on = 'hotel_id', how = 'inner').query('people_num == 1 & is_business')
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 14         r310    h_219        c_73 2017-03-30 01:52:36   2017-04-18  \
# 18        r1433    h_219       c_348 2017-04-08 03:19:47   2017-04-25
# 21        r2992    h_219       c_756 2016-02-17 14:02:23   2016-03-01
# 24        r3522    h_219       c_875 2016-09-09 07:10:21   2016-09-20
# 101          r7    h_256         c_1 2017-12-29 10:38:36   2018-01-25
# ...         ...      ...         ...                 ...          ...
# 4019      r1637    h_281       c_401 2018-02-07 01:21:25   2018-03-06
# 4022      r2620    h_281       c_653 2016-12-03 16:56:16   2016-12-08
# 4026      r3441    h_281       c_858 2018-01-12 19:58:51   2018-01-22
# 4027      r3465    h_281       c_863 2018-07-12 04:18:50   2018-08-04
# 4028      r3787    h_281       c_942 2016-07-31 13:33:15   2016-08-27
#
#      checkin_time checkout_date  people_num  total_price  log_no  base_price
# 14       11:00:00    2017-04-21           1        30900     5.0       10300  \
# 18       10:00:00    2017-04-28           1        30900     4.0       10300
# 21       12:00:00    2016-03-03           1        20600     1.0       10300
# 24       10:00:00    2016-09-21           1        10300     2.0       10300
# 101      10:30:00    2018-01-28           1       103500     7.0       34500
# ...           ...           ...         ...          ...     ...         ...
# 4019     09:00:00    2018-03-07           1        15900     6.0       15900
# 4022     10:00:00    2016-12-09           1        15900     4.0       15900
# 4026     11:30:00    2018-01-24           1        31800     7.0       15900
# 4027     09:30:00    2018-08-06           1        31800     6.0       15900
# 4028     09:00:00    2016-08-28           1        15900     3.0       15900
#
#      big_area_name small_area_name  hotel_latitude  hotel_longitude
# 14               B             B-3       35.644729       139.693389  \
# 18               B             B-3       35.644729       139.693389
# 21               B             B-3       35.644729       139.693389
# 24               B             B-3       35.644729       139.693389
# 101              C             C-1       38.237294       140.696131
# ...            ...             ...             ...              ...
# 4019             F             F-4       34.636730       132.569108
# 4022             F             F-4       34.636730       132.569108
# 4026             F             F-4       34.636730       132.569108
# 4027             F             F-4       34.636730       132.569108
# 4028             F             F-4       34.636730       132.569108
#
#       is_business
# 14           True
# 18           True
# 21           True
# 24           True
# 101          True
# ...           ...
# 4019         True
# 4022         True
# 4026         True
# 4027         True
# 4028         True
#
# [446 rows x 16 columns]

# %%
pd.merge(reserve_tb.query('people_num == 1'), hotel_tb.query('is_business'), on='hotel_id', how = 'inner')
# Out:
#     reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0           r7    h_256         c_1 2017-12-29 10:38:36   2018-01-25  \
# 1         r997    h_256       c_244 2016-10-15 22:47:40   2016-10-31
# 2        r2602    h_256       c_650 2016-05-10 00:42:56   2016-05-12
# 3        r3738    h_256       c_930 2017-04-12 09:53:00   2017-05-08
# 4          r11    h_183         c_2 2016-11-19 12:49:10   2016-12-08
# ..         ...      ...         ...                 ...          ...
# 441      r2766     h_56       c_698 2017-04-08 16:41:45   2017-05-03
# 442      r2983     h_56       c_753 2016-06-18 23:17:50   2016-07-13
# 443      r2839    h_231       c_715 2016-04-06 02:51:01   2016-04-08
# 444      r3476     h_43       c_866 2016-09-17 21:09:02   2016-10-03
# 445      r3539    h_262       c_880 2016-11-06 08:55:35   2016-11-11
#
#     checkin_time checkout_date  people_num  total_price  log_no  base_price
# 0       10:30:00    2018-01-28           1       103500     7.0       34500  \
# 1       10:30:00    2016-11-02           1        69000     3.0       34500
# 2       11:00:00    2016-05-14           1        69000     1.0       34500
# 3       11:30:00    2017-05-09           1        34500     4.0       34500
# 4       11:00:00    2016-12-11           1        29700     3.0        9900
# ..           ...           ...         ...          ...     ...         ...
# 441     12:30:00    2017-05-06           1        95700     3.0       31900
# 442     10:00:00    2016-07-14           1        31900     3.0       31900
# 443     09:00:00    2016-04-10           1        29200     1.0       14600
# 444     09:30:00    2016-10-04           1        18100     2.0       18100
# 445     12:30:00    2016-11-14           1        57000     4.0       19000
#
#     big_area_name small_area_name  hotel_latitude  hotel_longitude
# 0               C             C-1       38.237294       140.696131  \
# 1               C             C-1       38.237294       140.696131
# 2               C             C-1       38.237294       140.696131
# 3               C             C-1       38.237294       140.696131
# 4               G             G-4       33.595248       130.633567
# ..            ...             ...             ...              ...
# 441             C             C-3       38.435640       140.898354
# 442             C             C-3       38.435640       140.898354
# 443             A             A-3       35.914151       139.837520
# 444             B             B-1       35.437093       139.799077
# 445             C             C-3       38.434114       140.697486
#
#      is_business
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ..           ...
# 441         True
# 442         True
# 443         True
# 444         True
# 445         True
#
# [446 rows x 16 columns]

# %%
import gc

small_area_mst = hotel_tb.groupby(['big_area_name', 'small_area_name']).size().reset_index()
small_area_mst.columns = ['big_area_name', 'small_area_name', 'hotel_cnt']

small_area_mst['join_area_id'] = np.where(small_area_mst['hotel_cnt'] -1 >= 20, small_area_mst['small_area_name'], small_area_mst['big_area_name'])

small_area_mst = small_area_mst.drop(['hotel_cnt', 'big_area_name'], axis = 1)

base_hotel_mst = pd.merge(hotel_tb, small_area_mst, on = 'small_area_name').loc[:, ['hotel_id', 'join_area_id']]

del small_area_mst
gc.collect()

recommend_hotel_mst = pd.concat([hotel_tb[['small_area_name', 'hotel_id']].rename(columns = {'small_area_name': 'join_area_name', 'hotel_id': 'rec_hotel_id'}),
                                hotel_tb[['big_area_name', 'hotel_id']].rename(columns = {'big_area_name': 'join_area_id', 'hotel_id': 'rec_hotel_id'}),])

pd.merge(base_hotel_mst, recommend_hotel_mst, on='join_area_id').loc[:, ['hotel_id', 'rec_hotel_id']].query('hotel_id != rec_hotel_id')
# Out:
#      hotel_id rec_hotel_id
# 1         h_1         h_14
# 2         h_1         h_22
# 3         h_1         h_27
# 4         h_1         h_40
# 5         h_1         h_45
# ...       ...          ...
# 5568    h_220        h_226
# 5569    h_220        h_249
# 5570    h_220        h_271
# 5571    h_220        h_281
# 5572    h_220        h_296
#
# [5414 rows x 2 columns]

# %%
result = reserve_tb.groupby('customer_id').apply(lambda group: group.sort_values(by = 'reserve_datetime', axis = 0))

result['before_price'] = result['total_price'].groupby('customer_id').shift(periods = 2)

display(result)
# Out:
#                  reserve_id hotel_id customer_id    reserve_datetime
# customer_id
# c_1         0            r1     h_75         c_1 2016-03-06 13:09:42  \
#             1            r2    h_219         c_1 2016-07-16 23:39:55
#             2            r3    h_179         c_1 2016-09-24 10:03:17
#             3            r4    h_214         c_1 2017-03-08 03:20:10
#             4            r5     h_16         c_1 2017-09-05 19:50:37
# ...                     ...      ...         ...                 ...
# c_999       4023      r4024    h_244       c_999 2016-10-06 18:01:34
#             4024      r4025    h_160       c_999 2017-03-11 11:56:05
#             4025      r4026    h_129       c_999 2017-06-27 23:00:02
#             4026      r4027     h_97       c_999 2017-09-29 05:24:57
#             4027      r4028     h_27       c_999 2018-03-14 05:01:45
#
#                  checkin_date checkin_time checkout_date  people_num
# customer_id
# c_1         0      2016-03-26     10:00:00    2016-03-29           4  \
#             1      2016-07-20     11:30:00    2016-07-21           2
#             2      2016-10-19     09:00:00    2016-10-22           2
#             3      2017-03-29     11:00:00    2017-03-30           4
#             4      2017-09-22     10:30:00    2017-09-23           3
# ...                       ...          ...           ...         ...
# c_999       4023   2016-10-07     11:30:00    2016-10-09           3
#             4024   2017-03-27     10:00:00    2017-03-30           1
#             4025   2017-07-10     09:30:00    2017-07-11           2
#             4026   2017-10-09     10:30:00    2017-10-10           2
#             4027   2018-04-02     11:30:00    2018-04-04           2
#
#                   total_price  log_no  before_price
# customer_id
# c_1         0           97200     1.0           NaN
#             1           20600     2.0           NaN
#             2           33600     3.0       97200.0
#             3          194400     4.0       20600.0
#             4           68100     5.0       33600.0
# ...                       ...     ...           ...
# c_999       4023        59400     2.0           NaN
#             4024        37200     3.0       62400.0
#             4025        16000     4.0       59400.0
#             4026        41800     5.0       37200.0
#             4027        74800     6.0       16000.0
#
# [4030 rows x 11 columns]

# %%
result = reserve_tb.groupby('customer_id').apply(lambda x: x.sort_values(by = 'reserve_datetime', ascending = True)).reset_index(drop = True)

result['price_avg'] = pd.Series(
    result.groupby('customer_id')['total_price'].rolling(center = False, window = 3, min_periods =3).sum().reset_index(drop=True)
)

display(result)
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4024    h_244       c_999 2016-10-06 18:01:34   2016-10-07
# 4026      r4025    h_160       c_999 2017-03-11 11:56:05   2017-03-27
# 4027      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4028      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4029      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
#
#      checkin_time checkout_date  people_num  total_price  log_no  price_avg
# 0        10:00:00    2016-03-29           4        97200     1.0        NaN
# 1        11:30:00    2016-07-21           2        20600     2.0        NaN
# 2        09:00:00    2016-10-22           2        33600     3.0   151400.0
# 3        11:00:00    2017-03-30           4       194400     4.0   248600.0
# 4        10:30:00    2017-09-23           3        68100     5.0   296100.0
# ...           ...           ...         ...          ...     ...        ...
# 4025     11:30:00    2016-10-09           3        59400     2.0        NaN
# 4026     10:00:00    2017-03-30           1        37200     3.0   159000.0
# 4027     09:30:00    2017-07-11           2        16000     4.0   112600.0
# 4028     10:30:00    2017-10-10           2        41800     5.0    95000.0
# 4029     11:30:00    2018-04-04           2        74800     6.0   132600.0
#
# [4030 rows x 11 columns]

# %%
result = reserve_tb.groupby('customer_id').apply(lambda x: x.sort_values(by = 'reserve_datetime', ascending = True)).reset_index(drop =True)

result['price_avg'] = pd.Series(result.groupby('customer_id')['total_price'].rolling(center=False, window = 3, min_periods = 1).mean().reset_index(drop =True))

result['price_avg'] = result.groupby('customer_id')['price_avg'].shift(periods = 1)
display(result)
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4024    h_244       c_999 2016-10-06 18:01:34   2016-10-07
# 4026      r4025    h_160       c_999 2017-03-11 11:56:05   2017-03-27
# 4027      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4028      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4029      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
#
#      checkin_time checkout_date  people_num  total_price  log_no     price_avg
# 0        10:00:00    2016-03-29           4        97200     1.0           NaN
# 1        11:30:00    2016-07-21           2        20600     2.0  97200.000000
# 2        09:00:00    2016-10-22           2        33600     3.0  58900.000000
# 3        11:00:00    2017-03-30           4       194400     4.0  50466.666667
# 4        10:30:00    2017-09-23           3        68100     5.0  82866.666667
# ...           ...           ...         ...          ...     ...           ...
# 4025     11:30:00    2016-10-09           3        59400     2.0  62400.000000
# 4026     10:00:00    2017-03-30           1        37200     3.0  60900.000000
# 4027     09:30:00    2017-07-11           2        16000     4.0  53000.000000
# 4028     10:30:00    2017-10-10           2        41800     5.0  37533.333333
# 4029     11:30:00    2018-04-04           2        74800     6.0  31666.666667
#
# [4030 rows x 11 columns]

# %%
import pandas.tseries.offsets as offsets
import operator

sum_table = pd.merge(reserve_tb[['reserve_id', 'customer_id', 'reserve_datetime']], reserve_tb[['customer_id', 'reserve_datetime', 'total_price']]
                    .rename(columns = {'reserve_datetime': 'reserve_datetime_before'}), on='customer_id')

sum_table = sum_table[operator.and_(sum_table['reserve_datetime'] > sum_table['reserve_datetime_before'],
                                   sum_table['reserve_datetime'] + offsets.Day(-90) <= sum_table['reserve_datetime_before'] )].groupby('reserve_id')['total_price'].sum().reset_index()

sum_table.columns = ['reserve_id', 'total_price_sum']

pd.merge(reserve_tb, sum_table, on = 'reserve_id', how='left').fillna(0)
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000 2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000 2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price  log_no
# 0        10:00:00    2016-03-29           4        97200     1.0  \
# 1        11:30:00    2016-07-21           2        20600     2.0
# 2        09:00:00    2016-10-22           2        33600     3.0
# 3        11:00:00    2017-03-30           4       194400     4.0
# 4        10:30:00    2017-09-23           3        68100     5.0
# ...           ...           ...         ...          ...     ...
# 4025     09:30:00    2017-07-11           2        16000     4.0
# 4026     10:30:00    2017-10-10           2        41800     5.0
# 4027     11:30:00    2018-04-04           2        74800     6.0
# 4028     09:30:00    2016-05-13           4       540000     1.0
# 4029     09:00:00    2016-07-09           1        44100     2.0
#
#       total_price_sum
# 0                 0.0
# 1                 0.0
# 2             20600.0
# 3                 0.0
# 4                 0.0
# ...               ...
# 4025              0.0
# 4026              0.0
# 4027              0.0
# 4028              0.0
# 4029         540000.0
#
# [4030 rows x 11 columns]

# %%
import datetime 
from dateutil.relativedelta import relativedelta

month_mst = pd.DataFrame({
    'year_month': [(datetime.date(2017,1,1) + relativedelta(months = x)).strftime('%Y%m') for x in range(0,3)]
})

customer_tb['join_key'] = 0
month_mst['join_key'] = 0

customer_mst = pd.merge(customer_tb[['customer_id', 'join_key']], month_mst, on='join_key')

reserve_tb['year_month']= reserve_tb['checkin_date'].apply(lambda  x: pd.to_datetime(x, format = '%Y-%m-%d').strftime("%Y%m"))

summary_result = pd.merge(customer_mst, reserve_tb[['customer_id', 'year_month', 'total_price']], 
                          on = ['customer_id', 'year_month'], how ='left').groupby(['customer_id', 'year_month'])['total_price'].sum().reset_index()

summary_result = summary_result.fillna(0)

# %%
display(summary_result)
# Out:
#      customer_id year_month  total_price
# 0            c_1     201701          0.0
# 1            c_1     201702          0.0
# 2            c_1     201703     194400.0
# 3           c_10     201701          0.0
# 4           c_10     201702          0.0
# ...          ...        ...          ...
# 2995       c_998     201702          0.0
# 2996       c_998     201703          0.0
# 2997       c_999     201701          0.0
# 2998       c_999     201702          0.0
# 2999       c_999     201703      37200.0
#
# [3000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

train_data, test_data, train_target, test_target = train_test_split(production_tb.drop('fault_flg', axis = 1), production_tb[['fault_flg']], test_size = 0.2)

train_data = train_data.reset_index(drop =True)
test_data  =test_data.reset_index(drop=True)
train_target = train_target.reset_index(drop =True)
test_target  =test_target.reset_index(drop=True)

row_no_list = list(range(len(train_target)))

k_fold = KFold(n_splits = 4, shuffle = True)

for train_cv_no, test_cv_no in k_fold.split(row_no_list):
    train_cv = train_data.iloc[train_cv_no, :]
    test_cv = train_data.iloc[test_cv_no, :]

# %%
train_window_start = 1
train_window_end = 24
horizon  = 12
skip = 12

monthly_index_tb.sort_values(by = 'year_month')

while True:
    test_window_end = train_window_end  + horizon
    
    train = monthly_index_tb[train_window_start:train_window_end]
    test = monthly_index_tb[(train_window_end + 1): test_window_end]
    
    if test_window_end >= len(monthly_index_tb.index):
        break
    
    train_window_start += skip
    train_window_end += skip

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(sampling_strategy = 'auto', k_neighbors = 5, random_state = 71)

balance_data, balance_target = sm.fit_resample(production_tb[['length', 'thickness']], production_tb['fault_flg'])

# %%
balance_target
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1891     True
# 1892     True
# 1893     True
# 1894     True
# 1895     True
# Name: fault_flg, Length: 1896, dtype: bool

# %%
pd.pivot_table(reserve_tb, index = 'customer_id', columns = 'people_num', values = 'reserve_id', aggfunc=lambda x: len(x), fill_value = 0)
# Out:
# people_num   1  2  3  4
# customer_id
# c_1          2  2  2  2
# c_10         0  2  2  2
# c_100        2  1  2  0
# c_1000       1  0  0  1
# c_101        2  1  1  1
# ...         .. .. .. ..
# c_994        1  0  0  0
# c_995        2  2  1  3
# c_996        0  4  3  0
# c_997        0  1  1  0
# c_999        1  3  1  1
#
# [888 rows x 4 columns]

# %%
from scipy.sparse import csc_matrix

cnt_tb = reserve_tb.groupby(['customer_id', 'people_num'])['reserve_id'].size().reset_index()
cnt_tb.columns = ['customer_id', 'people_num', 'rsv_cnt']

customer_id = pd.Categorical(cnt_tb['customer_id'])
people_num = pd.Categorical(cnt_tb['people_num'])

display(csc_matrix((cnt_tb['rsv_cnt'], (customer_id.codes, people_num.codes)), shape = (len(customer_id.categories), len(people_num.categories))))
# Out:
# <888x4 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2366 stored elements in Compressed Sparse Column format>

# %%
type(40000/3)
# Out:
# float

# %%
int(40000/3)
# Out:
# 13333

# %%
float(40000/3)
# Out:
# 13333.333333333334

# %%
df = pd.DataFrame({'value' : [40000/3]})

# %%
df.dtypes
# Out:
# value    float64
# dtype: object

# %%
df['value'].astype('int8')
# Out:
# 0    21
# Name: value, dtype: int8

# %%
df['value'].astype(float)
# Out:
# 0    13333.333333
# Name: value, dtype: float64

# %%
reserve_tb['total_price_log'] = reserve_tb['total_price'].apply(lambda x: np.log10(x / 1000  + 1))

# %%
display(reserve_tb)
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000 2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000 2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price  log_no year_month
# 0        10:00:00    2016-03-29           4        97200     1.0     201603  \
# 1        11:30:00    2016-07-21           2        20600     2.0     201607
# 2        09:00:00    2016-10-22           2        33600     3.0     201610
# 3        11:00:00    2017-03-30           4       194400     4.0     201703
# 4        10:30:00    2017-09-23           3        68100     5.0     201709
# ...           ...           ...         ...          ...     ...        ...
# 4025     09:30:00    2017-07-11           2        16000     4.0     201707
# 4026     10:30:00    2017-10-10           2        41800     5.0     201710
# 4027     11:30:00    2018-04-04           2        74800     6.0     201804
# 4028     09:30:00    2016-05-13           4       540000     1.0     201605
# 4029     09:00:00    2016-07-09           1        44100     2.0     201607
#
#       total_price_log
# 0            1.992111
# 1            1.334454
# 2            1.539076
# 3            2.290925
# 4            1.839478
# ...               ...
# 4025         1.230449
# 4026         1.631444
# 4027         1.879669
# 4028         2.733197
# 4029         1.654177
#
# [4030 rows x 12 columns]

# %%
customer_tb['age_rank'] = (np.floor(customer_tb['age'] / 10) * 10).astype('category')
display(customer_tb)
# Out:
#     customer_id  age    sex  home_latitude  home_longitude  join_key age_rank
# 0           c_1   41    man      35.092193      136.512347         0     40.0
# 1           c_2   38    man      35.325076      139.410551         0     30.0
# 2           c_3   49  woman      35.120543      136.511179         0     40.0
# 3           c_4   43    man      43.034868      141.240314         0     40.0
# 4           c_5   31    man      35.102661      136.523797         0     30.0
# ..          ...  ...    ...            ...             ...       ...      ...
# 995       c_996   44    man      34.465648      135.373787         0     40.0
# 996       c_997   35    man      35.345372      139.413754         0     30.0
# 997       c_998   32  woman      43.062267      141.272126         0     30.0
# 998       c_999   48  woman      38.172800      140.464198         0     40.0
# 999      c_1000   39    man      35.452412      139.411310         0     30.0
#
# [1000 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler

reserve_tb['people_num'] = reserve_tb['people_num'].astype(float)

ss = StandardScaler()

result = ss.fit_transform(reserve_tb[['people_num', 'total_price']])

reserve_tb['people_num_norm'] = [x[0] for x in result]
reserve_tb['total_price_norm'] = [x[1] for x in result]

# %%
display(reserve_tb)
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000 2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000 2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price  log_no year_month
# 0        10:00:00    2016-03-29         4.0        97200     1.0     201603  \
# 1        11:30:00    2016-07-21         2.0        20600     2.0     201607
# 2        09:00:00    2016-10-22         2.0        33600     3.0     201610
# 3        11:00:00    2017-03-30         4.0       194400     4.0     201703
# 4        10:30:00    2017-09-23         3.0        68100     5.0     201709
# ...           ...           ...         ...          ...     ...        ...
# 4025     09:30:00    2017-07-11         2.0        16000     4.0     201707
# 4026     10:30:00    2017-10-10         2.0        41800     5.0     201710
# 4027     11:30:00    2018-04-04         2.0        74800     6.0     201804
# 4028     09:30:00    2016-05-13         4.0       540000     1.0     201605
# 4029     09:00:00    2016-07-09         1.0        44100     2.0     201607
#
#       total_price_log  people_num_norm  total_price_norm
# 0            1.992111         1.300709         -0.053194
# 1            1.334454        -0.483753         -0.747822
# 2            1.539076        -0.483753         -0.629935
# 3            2.290925         1.300709          0.828240
# 4            1.839478         0.408478         -0.317080
# ...               ...              ...               ...
# 4025         1.230449        -0.483753         -0.789536
# 4026         1.631444        -0.483753         -0.555575
# 4027         1.879669        -0.483753         -0.256323
# 4028         2.733197         1.300709          3.962229
# 4029         1.654177        -1.375984         -0.534718
#
# [4030 rows x 14 columns]

# %%
reserve_tb = reserve_tb[
    (abs(reserve_tb['total_price'] - np.mean(reserve_tb['total_price'])) / np.std(reserve_tb['total_price']) <= 3)
].reset_index()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

pca_values = pca.fit_transform(production_tb[['length', 'thickness']])

print('累積寄与率: {0}'.format(sum(pca.explained_variance_ratio_)))
print('各次元の寄与率: {0}'.format(pca.explained_variance_ratio_))
pca_newvalues = pca.transform(production_tb[['length', 'thickness']])
# Out:
# 累積寄与率: 1.0
# 各次元の寄与率: [0.97897794 0.02102206]

# %%
production_miss_num = production_miss_num.replace('None', np.nan)
production_miss_num['thickness'] = production_miss_num['thickness'].astype('float64')

thickness_mean = production_miss_num['thickness'].mean()
production_miss_num['thickness'] = production_miss_num['thickness'].fillna(thickness_mean)

# %%
display(production_miss_num)
# Out:
#     type      length  thickness  fault_flg
# 0      E  274.027383  40.241131      False
# 1      D   86.319269  16.906715      False
# 2      E  123.940388   1.018462      False
# 3      B  175.554886  16.414924      False
# 4      B  244.934740  29.061081      False
# ..   ...         ...        ...        ...
# 995    C  363.214163  48.369483      False
# 996    D  134.773797  26.861665      False
# 997    B  231.174985   7.087471      False
# 998    D   81.613510   5.716271      False
# 999    C  202.010973  35.211647       True
#
# [1000 rows x 4 columns]

# %%
#MICE

# %%
customer_tb[['sex_is_man']] = (customer_tb[['sex']] == 'man').astype('bool')

customer_tb['sex_c'] = pd.Categorical(customer_tb['sex'], categories=['man', 'woman'])

customer_tb['sex_c'].cat.codes
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    1
# 998    1
# 999    0
# Length: 1000, dtype: int8

# %%
customer_tb['sex_c'].cat.categories
# Out:
# Index(['man', 'woman'], dtype='object')

# %%
customer_tb['sex'] = pd.Categorical(customer_tb['sex'])

dummy_vars = pd.get_dummies(customer_tb['sex'], drop_first = False)

# %%
dummy_vars
# Out:
#        man  woman
# 0     True  False
# 1     True  False
# 2    False   True
# 3     True  False
# 4     True  False
# ..     ...    ...
# 995   True  False
# 996   True  False
# 997  False   True
# 998  False   True
# 999   True  False
#
# [1000 rows x 2 columns]

# %%
customer_tb['age_rank'] =  pd.Categorical(np.floor(customer_tb['age']/ 10) * 10)

customer_tb['age_rank'] = customer_tb['age_rank'].cat.add_categories(['over60'])
customer_tb.loc[customer_tb['age_rank'].isin([60,70,80,90]), 'age_rank'] = 'over60'

customer_tb['age_rank'] = customer_tb['age_rank'].cat.remove_unused_categories()

# %%
customer_tb
# Out:
#     customer_id  age    sex  home_latitude  home_longitude  join_key age_rank
# 0           c_1   41    man      35.092193      136.512347         0     40.0  \
# 1           c_2   38    man      35.325076      139.410551         0     30.0
# 2           c_3   49  woman      35.120543      136.511179         0     40.0
# 3           c_4   43    man      43.034868      141.240314         0     40.0
# 4           c_5   31    man      35.102661      136.523797         0     30.0
# ..          ...  ...    ...            ...             ...       ...      ...
# 995       c_996   44    man      34.465648      135.373787         0     40.0
# 996       c_997   35    man      35.345372      139.413754         0     30.0
# 997       c_998   32  woman      43.062267      141.272126         0     30.0
# 998       c_999   48  woman      38.172800      140.464198         0     40.0
# 999      c_1000   39    man      35.452412      139.411310         0     30.0
#
#      sex_is_man  sex_c
# 0          True    man
# 1          True    man
# 2         False  woman
# 3          True    man
# 4          True    man
# ..          ...    ...
# 995        True    man
# 996        True    man
# 997       False  woman
# 998       False  woman
# 999        True    man
#
# [1000 rows x 9 columns]

# %%
customer_tb['sex_and_age'] = pd.Categorical(customer_tb[['sex', 'age']].apply(lambda x: "{}_{}".format(np.int(x[1]/ 10) * 10, x[0]), axis = 1))
# Out:
# /var/folders/tl/3mcdykwx5g145dz_cpc1vdxc0000gn/T/ipykernel_1216/3214330239.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   customer_tb['sex_and_age'] = pd.Categorical(customer_tb[['sex', 'age']].apply(lambda x: "{}_{}".format(np.int(x[1]/ 10) * 10, x[0]), axis = 1))

# %%
customer_tb
# Out:
#     customer_id  age    sex  home_latitude  home_longitude  join_key age_rank
# 0           c_1   41    man      35.092193      136.512347         0     40.0  \
# 1           c_2   38    man      35.325076      139.410551         0     30.0
# 2           c_3   49  woman      35.120543      136.511179         0     40.0
# 3           c_4   43    man      43.034868      141.240314         0     40.0
# 4           c_5   31    man      35.102661      136.523797         0     30.0
# ..          ...  ...    ...            ...             ...       ...      ...
# 995       c_996   44    man      34.465648      135.373787         0     40.0
# 996       c_997   35    man      35.345372      139.413754         0     30.0
# 997       c_998   32  woman      43.062267      141.272126         0     30.0
# 998       c_999   48  woman      38.172800      140.464198         0     40.0
# 999      c_1000   39    man      35.452412      139.411310         0     30.0
#
#      sex_is_man  sex_c sex_and_age
# 0          True    man      40_man
# 1          True    man      30_man
# 2         False  woman    40_woman
# 3          True    man      40_man
# 4          True    man      30_man
# ..          ...    ...         ...
# 995        True    man      40_man
# 996        True    man      30_man
# 997       False  woman    30_woman
# 998       False  woman    40_woman
# 999        True    man      30_man
#
# [1000 rows x 10 columns]

# %%
fault_cnt_per_type = production_tb.query('fault_flg').groupby('type')['fault_flg'].count()

type_cnt = production_tb.groupby('type')['fault_flg'].count()

production_tb['type_fault_rate'] = production_tb[['type', 'fault_flg']].apply(lambda x: (fault_cnt_per_type[x[0]] - int(x[1])) / (type_cnt[x[0]] -1), axis = 1)

# %%
production_tb
# Out:
#     type      length  thickness  fault_flg  type_fault_rate
# 0      E  274.027383  40.241131      False         0.061224
# 1      D   86.319269  16.906715      False         0.032710
# 2      E  123.940388   1.018462      False         0.061224
# 3      B  175.554886  16.414924      False         0.034483
# 4      B  244.934740  29.061081      False         0.034483
# ..   ...         ...        ...        ...              ...
# 995    C  363.214163  48.369483      False         0.076190
# 996    D  134.773797  26.861665      False         0.032710
# 997    B  231.174985   7.087471      False         0.034483
# 998    D   81.613510   5.716271      False         0.032710
# 999    C  202.010973  35.211647       True         0.071429
#
# [1000 rows x 5 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

production_miss_cat =  production_miss_cat.replace('None', np.nan)

train = production_miss_cat.dropna(subset=['type'])
test = production_miss_cat.loc[production_miss_cat.index.difference(train.index), :]

kn = KNeighborsClassifier(n_neighbors=3)

kn.fit(train[['length', 'thickness']], train['type'])

test['type'] = kn.predict(test[['length', 'thickness']])

# %%
train
# Out:
#     type      length  thickness  fault_flg
# 0      E  274.027383  40.241131      False
# 1      D   86.319269  16.906715      False
# 2      E  123.940388   1.018462      False
# 3      B  175.554886  16.414924      False
# 4      B  244.934740  29.061081      False
# ..   ...         ...        ...        ...
# 994    C  224.496555  16.608346       True
# 995    C  363.214163  48.369483      False
# 997    B  231.174985   7.087471      False
# 998    D   81.613510   5.716271      False
# 999    C  202.010973  35.211647       True
#
# [900 rows x 4 columns]

# %%
test
# Out:
#     type      length  thickness  fault_flg
# 8      E  276.386631  29.899611      False
# 26     E  263.844324  34.664251      False
# 30     E  129.364736  21.346752      False
# 36     A  203.378972  30.286454      False
# 41     E  157.463166  11.166165      False
# ..   ...         ...        ...        ...
# 971    A  130.088061   0.207250      False
# 980    E  284.562824  49.211790      False
# 983    B  264.130761   4.560416      False
# 992    A  182.252364  33.314305      False
# 996    A  134.773797  26.861665      False
#
# [100 rows x 4 columns]

# %%
pd.to_datetime(reserve_tb['reserve_datetime'], format = '%Y-%m-%d %H:%M:%S')
# Out:
# 0      2016-03-06 13:09:42
# 1      2016-07-16 23:39:55
# 2      2016-09-24 10:03:17
# 3      2017-03-08 03:20:10
# 4      2017-09-05 19:50:37
#                ...
# 3927   2017-03-11 11:56:05
# 3928   2017-06-27 23:00:02
# 3929   2017-09-29 05:24:57
# 3930   2018-03-14 05:01:45
# 3931   2016-06-06 08:16:51
# Name: reserve_datetime, Length: 3932, dtype: datetime64[ns]

# %%
pd.to_datetime(reserve_tb['checkin_date'] + " " +  reserve_tb['checkin_time'], format = '%Y-%m-%d %H:%M:%S')
# Out:
# 0      2016-03-26 10:00:00
# 1      2016-07-20 11:30:00
# 2      2016-10-19 09:00:00
# 3      2017-03-29 11:00:00
# 4      2017-09-22 10:30:00
#                ...
# 3927   2017-03-27 10:00:00
# 3928   2017-07-10 09:30:00
# 3929   2017-10-09 10:30:00
# 3930   2018-04-02 11:30:00
# 3931   2016-07-06 09:00:00
# Length: 3932, dtype: datetime64[ns]

# %%
pd.to_datetime(reserve_tb['reserve_datetime'], format = '%Y-%m-%d %H:%M:%S').dt.date
# Out:
# 0       2016-03-06
# 1       2016-07-16
# 2       2016-09-24
# 3       2017-03-08
# 4       2017-09-05
#            ...
# 3927    2017-03-11
# 3928    2017-06-27
# 3929    2017-09-29
# 3930    2018-03-14
# 3931    2016-06-06
# Name: reserve_datetime, Length: 3932, dtype: object

# %%
pd.to_datetime(reserve_tb['checkin_date'] , format = '%Y-%m-%d').dt.date
# Out:
# 0       2016-03-26
# 1       2016-07-20
# 2       2016-10-19
# 3       2017-03-29
# 4       2017-09-22
#            ...
# 3927    2017-03-27
# 3928    2017-07-10
# 3929    2017-10-09
# 3930    2018-04-02
# 3931    2016-07-06
# Name: checkin_date, Length: 3932, dtype: object

# %%
reserve_tb['reserve_datetime'] = pd.to_datetime(reserve_tb['reserve_datetime'], format = '%Y-%m-%d %H:%M:%S')

reserve_tb['reserve_datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# 0       2016-03-06 13:09:42
# 1       2016-07-16 23:39:55
# 2       2016-09-24 10:03:17
# 3       2017-03-08 03:20:10
# 4       2017-09-05 19:50:37
#                ...
# 3927    2017-03-11 11:56:05
# 3928    2017-06-27 23:00:02
# 3929    2017-09-29 05:24:57
# 3930    2018-03-14 05:01:45
# 3931    2016-06-06 08:16:51
# Name: reserve_datetime, Length: 3932, dtype: object

# %%
reserve_tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3932 entries, 0 to 3931
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             3932 non-null   int64
#  1   reserve_id        3932 non-null   object
#  2   hotel_id          3932 non-null   object
#  3   customer_id       3932 non-null   object
#  4   reserve_datetime  3932 non-null   datetime64[ns]
#  5   checkin_date      3932 non-null   object
#  6   checkin_time      3932 non-null   object
#  7   checkout_date     3932 non-null   object
#  8   people_num        3932 non-null   float64
#  9   total_price       3932 non-null   int64
#  10  log_no            3932 non-null   float64
#  11  year_month        3932 non-null   object
#  12  total_price_log   3932 non-null   float64
#  13  people_num_norm   3932 non-null   float64
#  14  total_price_norm  3932 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(7)
# memory usage: 460.9+ KB

# %%
reserve_tb['checkin_datetime'] = pd.to_datetime(reserve_tb['checkin_date'] + ' '+ reserve_tb['checkin_time'], format = '%Y-%m-%d %H:%M:%S')
reserve_tb['checkin_datetime'].dt.year - reserve_tb['reserve_datetime'].dt.year
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3927    0
# 3928    0
# 3929    0
# 3930    0
# 3931    0
# Length: 3932, dtype: int32

# %%
(reserve_tb['checkin_datetime'].dt.year * 12 + reserve_tb['checkin_datetime'].dt.month) - (reserve_tb['reserve_datetime'].dt.year * 12 + reserve_tb['reserve_datetime'].dt.month)
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 3927    0
# 3928    1
# 3929    1
# 3930    1
# 3931    1
# Length: 3932, dtype: int32

# %%
(reserve_tb['checkin_datetime'] - reserve_tb['reserve_datetime']).dt.components
# Out:
#       days  hours  minutes  seconds  milliseconds  microseconds  nanoseconds
# 0       19     20       50       18             0             0            0
# 1        3     11       50        5             0             0            0
# 2       24     22       56       43             0             0            0
# 3       21      7       39       50             0             0            0
# 4       16     14       39       23             0             0            0
# ...    ...    ...      ...      ...           ...           ...          ...
# 3927    15     22        3       55             0             0            0
# 3928    12     10       29       58             0             0            0
# 3929    10      5        5        3             0             0            0
# 3930    19      6       28       15             0             0            0
# 3931    30      0       43        9             0             0            0
#
# [3932 rows x 7 columns]

# %%
import datetime

reserve_tb['reserve_date'] = reserve_tb['reserve_datetime'].dt.date
reserve_tb['reserve_datetime'] + datetime.timedelta(days = 1)
# Out:
# 0      2016-03-07 13:09:42
# 1      2016-07-17 23:39:55
# 2      2016-09-25 10:03:17
# 3      2017-03-09 03:20:10
# 4      2017-09-06 19:50:37
#                ...
# 3927   2017-03-12 11:56:05
# 3928   2017-06-28 23:00:02
# 3929   2017-09-30 05:24:57
# 3930   2018-03-15 05:01:45
# 3931   2016-06-07 08:16:51
# Name: reserve_datetime, Length: 3932, dtype: datetime64[ns]

# %%
reserve_tb['reserve_datetime'] + datetime.timedelta(seconds = 1)
# Out:
# 0      2016-03-06 13:09:43
# 1      2016-07-16 23:39:56
# 2      2016-09-24 10:03:18
# 3      2017-03-08 03:20:11
# 4      2017-09-05 19:50:38
#                ...
# 3927   2017-03-11 11:56:06
# 3928   2017-06-27 23:00:03
# 3929   2017-09-29 05:24:58
# 3930   2018-03-14 05:01:46
# 3931   2016-06-06 08:16:52
# Name: reserve_datetime, Length: 3932, dtype: datetime64[ns]

# %%
reserve_tb['reserve_datetime'] = pd.to_datetime(
    reserve_tb['reserve_datetime'], format = '%Y-%m-%d %H:%M:%S'
)

def to_season(month_num):
    season = 'winter'
    if 3 <= month_num <= 5:
        season = 'spring'
    elif 6  <= month_num <= 8:
        season = 'summer'
    elif 9 <= month_num <= 11:
        season = 'autumn'
    return season

reserve_tb['reserve_season'] = pd.Categorical(
    reserve_tb['reserve_datetime'].dt.month.apply(to_season),
    categories=['spring', 'summer', 'autumn', 'winter']
)

# %%
reserve_tb
# Out:
#       index reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0         0         r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1         1         r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2         2         r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3         3         r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4         4         r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...     ...        ...      ...         ...                 ...          ...
# 3927   4024      r4025    h_160       c_999 2017-03-11 11:56:05   2017-03-27
# 3928   4025      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 3929   4026      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 3930   4027      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
# 3931   4029      r4030    h_117      c_1000 2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price  log_no year_month
# 0        10:00:00    2016-03-29         4.0        97200     1.0     201603  \
# 1        11:30:00    2016-07-21         2.0        20600     2.0     201607
# 2        09:00:00    2016-10-22         2.0        33600     3.0     201610
# 3        11:00:00    2017-03-30         4.0       194400     4.0     201703
# 4        10:30:00    2017-09-23         3.0        68100     5.0     201709
# ...           ...           ...         ...          ...     ...        ...
# 3927     10:00:00    2017-03-30         1.0        37200     3.0     201703
# 3928     09:30:00    2017-07-11         2.0        16000     4.0     201707
# 3929     10:30:00    2017-10-10         2.0        41800     5.0     201710
# 3930     11:30:00    2018-04-04         2.0        74800     6.0     201804
# 3931     09:00:00    2016-07-09         1.0        44100     2.0     201607
#
#       total_price_log  people_num_norm  total_price_norm    checkin_datetime
# 0            1.992111         1.300709         -0.053194 2016-03-26 10:00:00  \
# 1            1.334454        -0.483753         -0.747822 2016-07-20 11:30:00
# 2            1.539076        -0.483753         -0.629935 2016-10-19 09:00:00
# 3928        1.725912         0.408478         -0.461265 2018-07-24 12:30:00
# 3929        2.224015         0.408478          0.575236 2018-10-02 12:00:00
# 3930        1.776701         0.408478         -0.401415 2018-03-15 11:00:00
# 3931        1.751279        -0.483753         -0.432247 2018-05-21 12:00:00
#
#      reserve_date reserve_season  target_day holidayday_flg
# 0      2016-03-06         spring  2016-03-26           True  \
# 1      2016-03-14         spring  2016-03-26           True
# 2      2016-03-21         spring  2016-03-26           True
# 3      2016-03-05         spring  2016-03-26           True
# 4      2016-03-21         spring  2016-03-26           True
# ...           ...            ...         ...            ...
# 3927   2018-04-10         spring  2018-04-10          False
# 3928   2018-07-02         summer  2018-07-24          False
# 3929   2018-09-10         autumn  2018-10-02          False
# 3930   2018-02-16         winter  2018-03-15          False
# 3931   2018-04-22         spring  2018-05-21          False
#
#       nextday_is_holiday_flg
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# ...                      ...
# 3927                   False
# 3928                   False
# 3929                   False
# 3930                   False
# 3931                   False
#
# [3932 rows x 21 columns]

# %%
import os 
import MeCab

mc = MeCab.Tagger()

with open('./data/txt/meros.txt', 'r') as  f:
    txt = f.read()
    
word_list = []
node = mc.parseToNode(txt)
while node:
    f = node.feature[0:2]
    if f == '名詞' or f == '動詞':
        word_list.append(node.surface)
    node = node.next

print(word_list)
# Out:
# ['メロス', '激怒', 'し', '邪智', '暴虐', '王', '除か', 'なら', '決意', 'し', 'メロス', '政治', 'わから', 'メロス', '村', '牧人', 'ある', '笛', '吹き', '羊', '遊ん', '暮し', '来', '邪悪', '対し', '人', '一', '倍', '敏感', 'あっ', 'きょう', '未明', 'メロス', '村', '出発', 'し', '野', '越え', '山越え', '十', '里', 'なれ', 'シラクス', '市', 'やっ', '来', 'メロス', '父', '母', '女房', '十', '六', '内気', '妹', '二人', '暮し', '妹', '村', '律気', '一', '牧人', '近々', '花婿', 'し', '迎える', '事', 'なっ', 'い', '結婚', '式', 'ある', 'メロス', 'ゆえ', '花嫁', '衣裳', '祝宴', '馳走', '買い', '市', 'やっ', '来', '品々', '買い集め', '都', '大路', '歩い', 'メロス', '竹馬', '友', 'あっ', 'セリヌンティウス', 'ある', '今', 'シラクス', '市', '石工', 'し', 'いる', '友', '訪ね', 'みる', 'つもり', '逢わ', '訪ね', '行く', '楽しみ', 'ある', '歩い', 'いる', 'うち', 'メロス', 'まち', '様子', '思っ', 'し', 'いる', '日', '落ち', 'まち', '夜', 'せい', '市', '全体', 'やけ', 'メロス', '不安', 'なっ', '来', '路', '逢っ', '若い衆', 'つかまえ', 'あっ', '二', '年', 'まえ', '市', '来', 'とき', '夜', '皆', '歌', 'うたっ', 'まち', 'あっ', '筈', '質問', 'し', '若い衆', '首', '振っ', '答え', '歩い', '老爺', '逢い', 'こんど', '語勢', 'し', '質問', 'し', '老爺', '答え', 'メロス', '両手', '老爺', 'からだ', 'ゆすぶっ', '質問', '重ね', '老爺', 'あたり', 'はばかる', '低声', '答え']

# %%
from  gensim import corpora, matutils

mc = MeCab.Tagger()
txt_word_list = []

files = os.listdir('./data/txt')
for file in files:
    with open('./data/txt/' + file, 'r') as f:
        txt = f.read()    
        word_list = []
        node = mc.parseToNode(txt)
        while node:
            f = node.feature[0:2]
            if f == '名詞' or f == '動詞':
                word_list.append(node.surface)
            node = node.next
                
    txt_word_list.append(word_list)
    
corpus_dic = corpora.Dictionary(txt_word_list)

corpus_list = [corpus_dic.doc2bow(word_in_text) for word_in_text in txt_word_list]

word_matrix = matutils.corpus2csc(corpus_list)

# %%
word_matrix
# Out:
# <219x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 234 stored elements in Compressed Sparse Column format>

# %%
from  gensim import matutils, models

tfidf_model = models.TfidfModel(corpus_list, normalize=True)

corpus_list_tfidf = tfidf_model[corpus_list]
word_matrix = matutils.corpus2csc(corpus_list_tfidf)

# %%
customer_tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     1000 non-null   object
#  1   age             1000 non-null   int64
#  2   sex             1000 non-null   category
#  3   home_latitude   1000 non-null   float64
#  4   home_longitude  1000 non-null   float64
#  5   join_key        1000 non-null   int64
#  6   age_rank        1000 non-null   category
#  7   sex_is_man      1000 non-null   bool
#  8   sex_c           1000 non-null   category
#  9   sex_and_age     1000 non-null   category
# dtypes: bool(1), category(4), float64(2), int64(2), object(1)
# memory usage: 45.2+ KB

# %%
import pyproj

def convert_to_continuous(x):
    x_min =  (x *  100 - int(x * 100)) * 100
    x_sec = ( x-int(x) - x_min / 10000) * 100
    return int(x) + x_sec / 60 + x_min /60  /60

customer_tb['home_latitude'] = customer_tb['home_latitude'].apply(lambda x : convert_to_continuous(x))
customer_tb['home_longitude'] = customer_tb['home_longitude'].apply(lambda x : convert_to_continuous(x))

epsg_world = pyproj.Proj('+init=EPSG:4326')

epsg_japan = pyproj.Proj('+init=EPSG:4301')

home_position= pyproj.transform(epsg_japan, epsg_world, customer_tb['home_longitude'].values, customer_tb['home_latitude'].values)

customer_tb['home_longitude'] = home_position[0]
customer_tb['home_latitude'] = home_position[1]
# Out:
# /Users/kazuyaaoki/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/kazuyaaoki/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/tl/3mcdykwx5g145dz_cpc1vdxc0000gn/T/ipykernel_1216/109564521.py:15: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   home_position= pyproj.transform(epsg_japan, epsg_world, customer_tb['home_longitude'].values, customer_tb['home_latitude'].values)

# %%
customer_tb
# Out:
#     customer_id  age    sex  home_latitude  home_longitude  join_key age_rank
# 0           c_1   41    man      38.389635      139.824168         0     40.0  \
# 1           c_2   38    man      39.506333      142.815171         0     30.0
# 2           c_3   49  woman      38.406537      141.017220         0     40.0
# 3           c_4   43    man      46.541226      143.204901         0     40.0
# 4           c_5   31    man      37.904632      140.936608         0     30.0
# ..          ...  ...    ...            ...             ...       ...      ...
# 995       c_996   44    man      38.603101      138.406665         0     40.0
# 996       c_997   35    man      38.180835      142.962207         0     30.0
# 997       c_998   32  woman      46.402996      144.069506         0     30.0
# 998       c_999   48  woman      40.562401      144.583861         0     40.0
# 999      c_1000   39    man      39.593517      142.391618         0     30.0
#
#      sex_is_man  sex_c sex_and_age
# 0          True    man      40_man
# 1          True    man      30_man
# 2         False  woman    40_woman
# 3          True    man      40_man
# 4          True    man      30_man
# ..          ...    ...         ...
# 995        True    man      40_man
# 996        True    man      30_man
# 997       False  woman    30_woman
# 998       False  woman    40_woman
# 999        True    man      30_man
#
# [1000 rows x 10 columns]

# %%
import math

from geopy.distance import great_circle, geodesic

pd.set_option('display.max_columns', 500)

_, _, reserve_tb = load_hotel_reserve()

#hotelの位置情報の書き換え

hotel_tb['hotel_latitude'] = hotel_tb['hotel_latitude'].apply(lambda x : convert_to_continuous(x))
hotel_tb['hotel_longitude'] = hotel_tb['hotel_longitude'].apply(lambda x : convert_to_continuous(x))

epsg_world = pyproj.Proj('+init=EPSG:4326')

epsg_japan = pyproj.Proj('+init=EPSG:4301')

hotel_position= pyproj.transform(epsg_japan, epsg_world, hotel_tb['hotel_longitude'].values, hotel_tb['hotel_latitude'].values)

hotel_tb['hotel_longitude'] = hotel_position[0]
hotel_tb['hotel_latitude'] = hotel_position[1]


reserve_tb = pd.merge(reserve_tb, customer_tb, on = 'customer_id', how = 'inner')
reserve_tb = pd.merge(reserve_tb, hotel_tb, on = 'hotel_id', how = 'inner')

display(reserve_tb)



#hotel_and_hotel_points = reserve_tb.loc[:, ['hotel_longitude', 'hotel_latitude', 'hotel_longitude', 'hotel_latitude']]
# Out:
# /Users/kazuyaaoki/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/kazuyaaoki/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/tl/3mcdykwx5g145dz_cpc1vdxc0000gn/T/ipykernel_1216/4095510941.py:18: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   hotel_position= pyproj.transform(epsg_japan, epsg_world, hotel_tb['hotel_longitude'].values, hotel_tb['hotel_latitude'].values)
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1          r185     h_75        c_43  2016-03-23 06:27:35   2016-04-07
# 2          r334     h_75        c_77  2016-08-17 19:29:12   2016-09-10
# 3          r783     h_75       c_191  2016-01-12 21:48:20   2016-01-22
# 4         r1276     h_75       c_311  2016-01-23 08:29:32   2016-02-05
# ...         ...      ...         ...                  ...          ...
# 4025      r3438    h_281       c_858  2017-03-16 12:48:56   2017-04-03
# 4026      r3441    h_281       c_858  2018-01-12 19:58:51   2018-01-22
# 4027      r3465    h_281       c_863  2018-07-12 04:18:50   2018-08-04
# 4028      r3787    h_281       c_942  2016-07-31 13:33:15   2016-08-27
# 4029      r3954    h_281       c_983  2016-06-01 02:59:49   2016-06-28
#
#      checkin_time checkout_date  people_num  total_price  age    sex
# 0        10:00:00    2016-03-29           4        97200   41    man  \
# 1        09:00:00    2016-04-10           4        97200   51    man
# 2        11:00:00    2016-09-13           1        24300   65  woman
# 3        12:30:00    2016-01-24           3        48600   71  woman
# 4        12:00:00    2016-02-07           4        64800   42  woman
# ...           ...           ...         ...          ...  ...    ...
# 4025     11:00:00    2017-04-04           3        47700   49  woman
# 4026     11:30:00    2018-01-24           1        31800   49  woman
# 4027     09:30:00    2018-08-06           1        31800   68  woman
# 4028     09:00:00    2016-08-28           1        15900   66    man
# 4029     11:30:00    2016-07-01           2        95400   62  woman
#
#       home_latitude  home_longitude  join_key age_rank  sex_is_man  sex_c
# 0         38.389635      139.824168         0     40.0        True    man  \
# 1         37.486876      135.077971         0     50.0        True    man
# 2         42.291268      143.914859         0   over60       False  woman
# 3         38.374839      140.172349         0   over60       False  woman
# 4         39.422990      142.399159         0     40.0       False  woman
# ...             ...             ...       ...      ...         ...    ...
# 4025      38.173216      137.198582         0     40.0       False  woman
# 4026      38.173216      137.198582         0     40.0       False  woman
# 4027      40.200398      143.626403         0   over60       False  woman
# 4028      37.602021      139.997691         0   over60        True    man
# 4029      38.067143      137.790884         0   over60       False  woman
#
#      sex_and_age  base_price big_area_name small_area_name  hotel_latitude
# 0         40_man        8100             B             B-2       36.920385  \
# 1         50_man        8100             B             B-2       36.920385
# 2       60_woman        8100             B             B-2       36.920385
# 3       70_woman        8100             B             B-2       36.920385
# 4       40_woman        8100             B             B-2       36.920385
# ...          ...         ...           ...             ...             ...
# 4025    40_woman       15900             F             F-4       35.216832
# 4026    40_woman       15900             F             F-4       35.216832
# 4027    60_woman       15900             F             F-4       35.216832
# 4028      60_man       15900             F             F-4       35.216832
# 4029    60_woman       15900             F             F-4       35.216832
#
#       hotel_longitude  is_business
# 0          140.469316        False
# 1          140.469316        False
# 2          140.469316        False
# 3          140.469316        False
# 4          140.469316        False
# ...               ...          ...
# 4025       134.001097         True
# 4026       134.001097         True
# 4027       134.001097         True
# 4028       134.001097         True
# 4029       134.001097         True
#
# [4030 rows x 24 columns]

# %%
home_and_hotel_points = reserve_tb.loc[:, ['home_longitude', 'home_latitude', 'hotel_longitude', 'hotel_latitude']]

g = pyproj.Geod(ellps = 'WGS84')

home_to_hotel = home_and_hotel_points.apply(lambda x: g.inv(x[0], x[1], x[2], x[3]), axis = 1)

[x[2] for x in home_to_hotel]
# Out:
# [172722.03230659224,
#  482652.14487000235,
#  665543.5631575162,
#  163542.80226247874,
#  325191.65047346544,
#  650338.4193317991,
#  289689.7279297012,
#  555233.526926404,
#  1050276.8827782162,
#  349490.52364593523,
#  57374.58951959675,
#  361192.44347987836,
#  243651.14549149174,
#  978190.0148366196,
#  1103470.756411433,
#  1131598.1177716977,
#  709259.6588988191,
#  295068.46871191775,
#  140735.08739302531,
#  513680.8735050758,
#  1088004.8628922275,
#  339752.97079157486,
#  392380.9251889555,
#  414629.9374718122,
#  353600.2513427553,
#  914856.4636591835,
#  1012832.3453988811,
#  1218135.151720136,
#  395890.3118496062,
#  743223.817263964,
#  1678471.2675908336,
#  807813.5220012963,
#  1060290.458290112,
#  938399.410222678,
#  1795317.790349105,
#  1175776.0679294579,
#  415394.4927174872,
#  1407599.0923320616,
#  742069.828841901,
#  1014522.0787918628,
#  692657.8030029964,
#  399609.4809210039,
#  1578768.7499044116,
#  1142669.9221969564,
#  223620.90799933908,
#  205837.43022239188,
#  183362.2940212547,
#  492617.72675501544,
#  59655.12031716985,
#  226802.01249260348,
#  170339.22722781423,
#  639700.2672575974,
#  296090.3870767512,
#  855352.1600422058,
#  237748.32827543528,
#  182083.12608801454,
#  716069.4089678336,
#  837442.6240986022,
#  470340.53934300266,
#  235309.45525784214,
#  115418.78735155181,
#  50161.679890101324,
#  1101358.3999040162,
#  1161378.3911106593,
#  249234.16808254665,
#  217480.26546336745,
#  701990.2248830241,
#  728495.0146969572,
#  674349.4763633546,
#  96264.54189081273,
#  391589.37358564266,
#  34978.98463215758,
#  183751.75185717634,
#  83675.48608416194,
#  371478.858520194,
#  613850.1261810556,
#  423100.5681795064,
#  127583.08407765324,
#  686177.2259441076,
#  274358.6174000614,
#  363818.52155906754,
#  274576.0214696708,
#  808631.2366868102,
#  190919.31096724948,
#  489149.7653341398,
#  273044.7791202815,
#  214660.4813286077,
#  199118.62423421151,
#  192137.43293713033,
#  76365.59662874637,
#  613947.3921191803,
#  673286.4607482867,
#  567540.4776499048,
#  357673.1018110954,
#  676341.0585825524,
#  575327.6691372264,
#  757863.3784361443,
#  282666.23505785863,
#  590046.93616978,
#  565780.549214143,
#  129273.8013996793,
#  473726.5741802282,
#  179993.00337947547,
#  179993.00337947547,
#  601367.493270164,
#  288102.039346876,
#  573683.4605642388,
#  450619.6415264717,
#  1138791.46574662,
#  227925.8285273311,
#  564637.8018361032,
#  392375.49586914695,
#  311126.4776165819,
#  682626.2011636039,
#  523776.9349081666,
#  482284.7272934941,
#  565874.4939083385,
#  565874.4939083385,
#  54465.50122738594,
#  670943.843077681,
#  1021117.2868341582,
#  1016134.524936458,
#  554709.4989542282,
#  1034514.4739276337,
#  505677.0901512745,
#  719285.6082287445,
#  426614.90256463765,
#  965906.894658747,
#  137048.785822723,
#  143917.46094920952,
#  255359.66821643448,
#  1112919.4135813206,
#  1020901.2339256369,
#  716189.4569824111,
#  365927.3766535143,
#  241349.7827408184,
#  531478.9965950326,
#  574377.2928814455,
#  203051.9196360823,
#  912539.2480179309,
#  731443.2135280414,
#  310488.34875258955,
#  324830.5438205742,
#  385108.7651461748,
#  228429.32530819558,
#  526684.9485599719,
#  574002.1146949473,
#  1016127.8891588046,
#  355072.2840606771,
#  42600.38994983742,
#  246680.48862304274,
#  974235.3634471513,
#  360866.65811795194,
#  357256.92685663176,
#  573762.7452025565,
#  176846.35744391696,
#  1160806.9895455388,
#  1109628.9135745636,
#  825231.3319356053,
#  909610.0995220846,
#  968549.8829367391,
#  406108.8659230161,
#  406108.8659230161,
#  1402873.6979686776,
#  547213.4256722712,
#  594326.9818096528,
#  369791.96058736515,
#  554270.2345676189,
#  1173259.1317644739,
#  616572.6991273939,
#  1080773.096828633,
#  1499405.2579622907,
#  841486.2390859833,
#  656962.2493540925,
#  232431.65245630968,
#  619135.0554267438,
#  270197.5904455112,
#  812081.7802581395,
#  88721.7898659218,
#  304632.83093241294,
#  623233.9279881903,
#  588276.2814654665,
#  408326.6119888226,
#  759463.5223617448,
#  718593.8435580288,
#  69382.37009017843,
#  723276.7546682068,
#  443748.8882237255,
#  1698930.3464289345,
#  1260097.3050054016,
#  1635282.3155518179,
#  1043614.0229926273,
#  578074.3571347211,
#  1046575.8998995638,
#  1650209.5554498464,
#  942242.7619196658,
#  677514.0261134731,
#  1044381.7943424738,
#  730753.2548858416,
#  1056045.0829374173,
#  687880.0195022009,
#  311793.9597776018,
#  323242.2090501093,
#  274913.91575083806,
#  427173.0315254234,
#  142626.7010699728,
#  338076.01767165225,
#  258756.61031612896,
#  245388.98508233298,
#  464890.28262427973,
#  484091.2786419795,
#  514951.37857170386,
#  524346.0877460667,
#  310725.07960933284,
#  269564.2818437886,
#  553699.4266618498,
#  80679.79217997156,
#  499993.39329447557,
#  90228.13874024076,
#  264792.2739371592,
#  716052.4486044935,
#  30790.10044628975,
#  134307.67319912417,
#  115335.25289881392,
#  115335.25289881392,
#  432392.8730270156,
#  386097.4504356521,
#  843404.4957759742,
#  468036.6148730017,
#  9077.830710650036,
#  9077.830710650036,
#  651393.5497566808,
#  56640.42370108051,
#  186856.12275393537,
#  595648.1117298134,
#  599963.4998465456,
#  105674.37477125398,
#  709386.6991466534,
#  466527.1033576459,
#  576839.9404794087,
#  533392.629576925,
#  181277.88251148266,
#  613126.0025555763,
#  304736.37510086555,
#  307700.0968613328,
#  207000.83363500691,
#  402538.3107288556,
#  77118.95333562414,
#  301113.9563869876,
#  1119420.9603662163,
#  1143607.3040317025,
#  272220.5579518909,
#  176435.67180360382,
#  568193.9608301183,
#  1149385.9185835593,
#  298943.8932433868,
#  484359.44358648214,
#  502201.53079282725,
#  343365.365627296,
#  466055.2555503791,
#  721142.9824206202,
#  511789.2092185777,
#  214828.15482478193,
#  903026.3347938259,
#  250249.55742987778,
#  1204862.428199318,
#  478735.17193870014,
#  784784.5550439174,
#  143817.01086361034,
#  1143011.5695005425,
#  581599.9291554622,
#  731084.0620304836,
#  96426.15552225831,
#  425180.1843442916,
#  276963.99318679696,
#  174898.7412294478,
#  771175.603591542,
#  162797.7624469845,
#  306905.3421883748,
#  191962.60160233636,
#  271420.7326781407,
#  120388.00249237109,
#  262302.22154673137,
#  624099.4627717623,
#  128349.59789656998,
#  409014.6190674909,
#  74234.17345202985,
#  729224.1143541719,
#  427914.9413959703,
#  373868.04762511415,
#  207454.86032071256,
#  609336.4343076831,
#  759823.1698967778,
#  793975.115474649,
#  457936.1147380992,
#  1029560.5029675935,
#  971445.2811717718,
#  857181.1534995319,
#  994317.2640070391,
#  305064.4366838653,
#  614927.6932901402,
#  380535.7330306521,
#  346976.4593711048,
#  418312.93178988725,
#  1025058.5758027739,
#  610042.5009561784,
#  719703.9924183829,
#  1035121.0217892571,
#  812555.4205765952,
#  498654.9476496555,
#  996385.090903001,
#  564589.7670422747,
#  746931.9419051309,
#  453042.4803065172,
#  291356.64721251803,
#  621977.8428634845,
#  626264.281231887,
#  557562.2707055755,
#  626633.9610334025,
#  667272.699288142,
#  519390.5802595154,
#  169779.566975856,
#  616359.5979502172,
#  710148.5325483648,
#  305970.8454622924,
#  643564.9172040459,
#  361199.87845366565,
#  195248.16179061966,
#  976852.8835840205,
#  217288.5720501185,
#  536707.8389554959,
#  229762.50123936357,
#  996936.9044440574,
#  101668.32116904753,
#  300614.4383856942,
#  572276.8979696857,
#  1104087.2100034603,
#  993832.5976239693,
#  260133.38437518768,
#  534210.828061602,
#  647476.4655714723,
#  938162.0851311885,
#  597973.0903989731,
#  466857.66299361916,
#  664107.2732239384,
#  249647.4029415645,
#  220988.72339129352,
#  536405.0965225535,
#  686023.7187586493,
#  499530.3865383709,
#  499530.3865383709,
#  535812.8436945268,
#  173229.6772258931,
#  566160.7945022121,
#  368468.51207318547,
#  315323.1067103569,
#  301531.60335907503,
#  251662.38383894556,
#  460277.2056774017,
#  579402.8151648412,
#  1199002.1600024295,
#  135179.6571932257,
#  137869.92585306478,
#  1548330.1394227115,
#  836746.2448108362,
#  270658.3958777265,
#  1129629.2189898936,
#  958152.3100517485,
#  599133.0206721665,
#  812175.489169731,
#  211812.30587384882,
#  498418.3113848012,
#  324072.84955957363,
#  287799.48360380245,
#  323679.2265197959,
#  272455.34880785615,
#  1142201.359180008,
#  1105675.6340033293,
#  566456.0427675913,
#  447816.7779297039,
#  312432.1444837529,
#  1095847.976356159,
#  341196.06144217245,
#  1528879.48403785,
#  856897.862347187,
#  660877.941402852,
#  1141228.8087797905,
#  316078.8348081396,
#  680000.2374652373,
#  796556.0243698627,
#  1468453.9340157122,
#  1480565.2517703602,
#  262884.69657697366,
#  1102682.1799195108,
#  305935.11088622396,
#  298278.18737487996,
#  320137.43278797,
#  362788.32065688574,
#  481422.67306395003,
#  291189.0568784143,
#  1139937.0163007078,
#  444340.14036455425,
#  432191.2152251836,
#  124588.12864400979,
#  285589.9218078389,
#  199443.6503859481,
#  847960.7186206422,
#  959204.1973956906,
#  511951.05040647136,
#  550935.9808630609,
#  339326.68706510926,
#  233544.34299322485,
#  577891.25056142,
#  608184.4518974125,
#  218280.53151520266,
#  698658.2124104914,
#  340849.8880023092,
#  300720.70888305316,
#  207144.7817603381,
#  111880.18188149935,
#  166615.4975926701,
#  708440.353685,
#  597910.8492915904,
#  538684.2391006248,
#  602187.8271334622,
#  489430.2830617128,
#  573370.9682330864,
#  685100.099855619,
#  740431.3844722131,
#  213187.418540604,
#  607774.5801823682,
#  671438.941812232,
#  1080594.880679786,
#  390548.2782852793,
#  478419.77534015075,
#  ...]

# %%
home_and_hotel_points.apply(lambda x: great_circle((x[1], x[0]), (x[3], x[2])).meters, axis = 1)
# Out:
# 0       1.729623e+05
# 1       4.815574e+05
# 2       6.660272e+05
# 3       1.638276e+05
# 4       3.253992e+05
#             ...
# 4025    4.350690e+05
# 4026    4.350690e+05
# 4027    1.011014e+06
# 4028    5.984259e+05
# 4029    4.633617e+05
# Length: 4030, dtype: float64

# %%
home_and_hotel_points.apply(lambda x: geodesic((x[1], x[0]), (x[3], x[2])).meters, axis = 1)
# Out:
# 0       1.727220e+05
# 1       4.826521e+05
# 2       6.655436e+05
# 3       1.635428e+05
# 4       3.251917e+05
#             ...
# 4025    4.350043e+05
# 4026    4.350043e+05
# 4027    1.012138e+06
# 4028    5.992919e+05
# 4029    4.634965e+05
# Length: 4030, dtype: float64

# %%
def hubeny(lon1,lat1, lon2, lat2, a = 6378137, b = 6356752.314245):
    e2 = (a ** 2 - b ** 2) / a**2
    (lon1, lat1, lon2, lat2) = [ x * ( 2 * math.pi) / 360 for x in (lon1, lat1, lon2, lat2)]
    w = 1 - e2 * math.sin((lat1 + lat2) / 2) ** 2
    c2 = math.cos((lat1 + lat2) / 2 ) ** 2
    return math.sqrt((b ** 2 / w ** 3) * (lat1- lat2) ** 2 + (a ** 2 / w) * c2 * (lon1 - lon2) ** 2 )

home_and_hotel_points.apply(lambda x: hubeny(x[0], x[1], x[2], x[3]), axis = 1)
# Out:
# 0       1.732415e+05
# 1       4.827491e+05
# 2       6.674958e+05
# 3       1.640792e+05
# 4       3.260117e+05
#             ...
# 4025    4.359013e+05
# 4026    4.359013e+05
# 4027    1.014095e+06
# 4028    5.998550e+05
# 4029    4.643072e+05
# Length: 4030, dtype: float64

# %%
import redshift_connector

conn = redshift_connector.connect(
    host = 'redshift-cluster-1.cxhdo14m01ng.ap-northeast-1.redshift.amazonaws.com',
    database = 'dev',
    port = 5439,
    user = 'kazuya4645',
    password = 'Sisan1ok'
)

# %%
from scipy.sparse import csr_matrix
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import psycopg2
#       2 import os
#       3 from scipy.sparse import csr_matrix
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/psycopg2/__init__.py:51, in <module>
#       1 """A Python driver for PostgreSQL
#       2
#       3 psycopg is a PostgreSQL_ database adapter for the Python_ programming
#    (...)
#      17     TimeFromTicks, Timestamp, TimestampFromTicks
#      18 """
#      19 # psycopg/__init__.py - initialization of the psycopg module
#      20 #
#      21 # Copyright (C) 2003-2019 Federico Di Gregorio  <fog@debian.org>
#    (...)
#      48
#      49 # Import the DBAPI-2.0 stuff into top-level module.
# ---> 51 from psycopg2._psycopg import (                     # noqa
#      52     BINARY, NUMBER, STRING, DATETIME, ROWID,
#      53
#      54     Binary, Date, Time, Timestamp,
#      55     DateFromTicks, TimeFromTicks, TimestampFromTicks,
#      56
#      57     Error, Warning, DataError, DatabaseError, ProgrammingError, IntegrityError,
#      58     InterfaceError, InternalError, NotSupportedError, OperationalError,
#      59
#      60     _connect, apilevel, threadsafety, paramstyle,
#      61     __version__, __libpq_version__,
#      62 )
#      65 # Register default adapters.
#      67 from psycopg2 import extensions as _ext
#
# ImportError: dlopen(/Users/kazuyaaoki/.pyenv/versions/3.10.3/lib/python3.10/site-packages/psycopg2/_psycopg.cpython-310-darwin.so, 0x0002): Library not loaded: /usr/local/opt/postgresql/lib/libpq.5.dylib
#   Referenced from: <686689D6-0C46-39D7-ACE7-538F69AABAA0> /Users/kazuyaaoki/.pyenv/versions/3.10.3/lib/python3.10/site-packages/psycopg2/_psycopg.cpython-310-darwin.so
#   Reason: tried: '/usr/local/opt/postgresql/lib/libpq.5.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/postgresql/lib/libpq.5.dylib' (no such file), '/usr/local/opt/postgresql/lib/libpq.5.dylib' (no such file), '/usr/local/lib/libpq.5.dylib' (no such file), '/usr/lib/libpq.5.dylib' (no such file, not in dyld cache), '/usr/local/Cellar/postgresql@14/14.9/lib/libpq.5.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/Cellar/postgresql@14/14.9/lib/libpq.5.dylib' (no such file), '/usr/local/Cellar/postgresql@14/14.9/lib/libpq.5.dylib' (no such file), '/usr/local/lib/libpq.5.dylib' (no such file), '/usr/lib/libpq.5.dylib' (no such file, not in dyld cache)
