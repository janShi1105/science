# %%
import pandas as pd
from sklearn.datasets import load_boston

import pandas as pd
import urllib.request
from io import StringIO

url = "https://raw.githubusercontent.com/scikit-learn/scikit-learn/main/sklearn/datasets/data/boston_house_prices.csv"

#
def read_csv(url):
    print(url)
    res = urllib.request.urlopen(url)
    res = res.read().decode("utf-8")
    df = pd.read_csv(StringIO(res))
    return df

df = read_csv(url)
#実行
#read_csv(url)
#columns = ['CRIM', 'ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATTO', 'B', 'LSTAT', 'MEDV']
#df = pd.read_csv('https://github.com/scikit-learn/scikit-learn/blob/main/sklearn/datasets/data/boston_house_prices.csv', header=None)
df.columns = ['CRIM', 'ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATTO', 'B', 'LSTAT', 'MEDV']
df = df.drop([0])
df.head()
# Out:
# https://raw.githubusercontent.com/scikit-learn/scikit-learn/main/sklearn/datasets/data/boston_house_prices.csv
#       CRIM  ZN INDUS CHAS    NOX     RM   AGE     DIS RAD  TAX PTRATTO  \
# 1  0.00632  18  2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 2  0.02731   0  7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 3  0.02729   0  7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 4  0.03237   0  2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 5  0.06905   0  2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
#
#         B LSTAT  MEDV
# 1   396.9  4.98    24
# 2   396.9  9.14  21.6
# 3  392.83  4.03  34.7
# 4  394.63  2.94  33.4
# 5   396.9  5.33  36.2
